# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from IPython.display import HTML, display, Markdown, clear_output
import random 
import time

kelompok = [
    "David Nalendra dkk.",
    "Hanafi Firdaus dkk.",
    "Ahmad Nasikin dkk.",
    "Fatchur Berlianto dkk.",
    "Fatati Sriwahyuni dkk.",
    "Imam Arsandi Nalendra dkk.",
    "Anas Faisal dkk.",
    "Arifudin dkk.",
    "Eko Adi Nugroho dkk.",
    "Arief Styo Adi dkk.",
    "Fairuz Sufi Aziz dkk."    
]

kelompok2 = []

# %%
rolling = 1000
last_selected = ""

while rolling > 0:           
    rolling -= 1
    last_selected = random.sample(kelompok,1)[0]
    display(Markdown(f'# {last_selected}')) 
    clear_output()

display(Markdown(f'# {last_selected}'))
kelompok2.append(last_selected)
kelompok.remove(last_selected)    
print("On The Queue:", len(kelompok))
print("Urutan Kelompok:")

for i, kel in enumerate(kelompok2):
    print(i+1, kel)
# Out:
# # Eko Adi Nugroho dkk.
# On The Queue: 0
# Urutan Kelompok:
# 1 Arifudin dkk.
# 2 Fatati Sriwahyuni dkk.
# 3 Arief Styo Adi dkk.
# 4 David Nalendra dkk.
# 5 Imam Arsandi Nalendra dkk.
# 6 Fairuz Sufi Aziz dkk.
# 7 Hanafi Firdaus dkk.
# 8 Fatchur Berlianto dkk.
# 9 Anas Faisal dkk.
# 10 Ahmad Nasikin dkk.
# 11 Eko Adi Nugroho dkk.
