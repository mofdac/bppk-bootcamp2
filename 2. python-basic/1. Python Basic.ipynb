# %% [markdown]
# ## Dasar Pemrograman Python
#
# #### Oleh: Reza Rizky Pratama & Bakhtiar Amaludin
# #### MoF-DAC

# %% [markdown]
# ## Sebelum memulai
#
# ### Pastikan
#
# - Anaconda sudah terinstall ✅
# - Bisa membuka jupyter notebook ✅
# - Sudah menonton Video MOF-DAC Python Part 1 dan Part 2? 👨‍💻

# %% [markdown]
# ## Python Dasar - MoFDAC

# %%
from IPython.display import HTML

HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/rwrj0ilTVak" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/rwrj0ilTVak" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/55HIBpr0Mcg" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/55HIBpr0Mcg" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## Apa itu Python 🐍 ?
#
# - Python merupakan *bahasa pemrograman* tingkat tinggi yang diracik oleh Guido van Rossum.
#
# - Python banyak digunakan untuk membuat berbagai macam program, seperti: Data Science, Aplikasi desktop, Aplikasi Mobile, Web, IoT, Game, Program untuk Hacking, dsb.
#
# - Python juga dikenal dengan bahasa pemrograman yang mudah dipelajari, karena struktur sintaknya rapi dan mudah dipahami.
#
# - Python bagus untuk pemula yang belum pernah coding
#
# ## Bahasa Pemrograman?
#
# Bahasa pemrograman _(programming language)_ adalah sebuah cara manusia memberikan melalui instruksi standar kepada mesin/komputer agar melakukan sesuatu

# %% [markdown]
# ## Pemanasan: Python Calculator 🧮
#
# Untuk mengawali belajar python hari ini, mari bermain-main dengan kalkulator!
#
# | Operator| 	Contoh	 |
# | --- | --- |
# | Penjumlahan `+`| 	`1 + 3 = 4` |
# | Pengurangan `-`| 	`4 - 1 = 3`	 |
# | Perkalian `*`| 	`2 * 4 = 8`	 |
# | Pembagian `/`| 	`10 / 5 = 2`|
# | Sisa Bagi `%`| 	`11 % 2 = 1`|
# | Pangkat `**`| 	`8 ** 2 = 64`|
# | Pembagian Bulat `//`| 	`10 // 3 = 3` |

# %%
# Gunakan Python sebagai Kalkulator
3 + 15 + 4 * 4
# Out:
# 34

# %% [markdown]
# ## Tetapi...
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Materi
#
# - Syntax Dasar
# - Variable
# - Tipe Data
# - Arithmatic Operator
# - Logical Operator
# - Function
# - Data Structure
# - Flow Control
# - Libraries

# %% [markdown]
# ## Syntax Dasar Python

# %% [markdown]
# ### Lines, Indentation dan Komentar
# - Python menggunakan indentasi untuk menyusun blok baris kode.
# - Komentar dimulai dengan # adalah baris yang tidak akan dieksekusi di python
#
# ### Statement in Multiple Line
# Secara umum perintah diakhiri dengan baris baru. Namun, Python juga mendukung penggunaan karakter (\\) untuk membuat satu perintah dijalankan pada beberapa baris
#
# ### Multiple Statement in One Line
# Berkebalikan dengan _Statement in Multiple Line_, kita bisa menggunakan karakter (;) untuk membuat beberapa perintah dalam satu baris
#
#
# ```python
# # Contoh Komentar Block:
# if True:
#    print(True)
# else:
#    print(False)
#
# ### Beberapa Statement satu baris
# x = 'satu'; y = 'dua'
#
# ### Statement beberapa baris
# total = 1 + \
#         2 + \
#         3
#
# ```

# %%
# Komentar 

### Beberapa Statement satu baris

### Statement beberapa baris

# %% [markdown]
# ### Reserved Words
# - and
# - exec
# - not
# - assert
# - finally
# - or
# - break
# - for
# - pass

# %% [markdown]
# ## Variable
#
# ![image-2.png](attachment:image-2.png)
#
# - Variabel adalah lokasi memori yang dicadangkan untuk menyimpan nilai-nilai.
# - Kaidah Penulisan variabel Python:
#
#     - Karakter pertama harus berupa huruf atau garis bawah/underscore _
#     - Tidak boleh ada spasi
#     - Karakter selanjutnya dapat berupa huruf, garis bawah/underscore _ atau angka
#     - Karakter pada nama variabel bersifat sensitif (case-sensitif).
#     - Tidak bisa menggunakan reserved words

# %% [markdown]
# ## Naming Case
# Snake Case : nama_variable
#
# Camel Case : namaVariable
#
# Pascal Case : NamaVariable

# %%
# kembali ke kalkulator
3 + 10 + 4 * 2
# Out:
# 21

# %% [markdown]
# # Assignment Operator
#
# Adalah operator yang digunakan untuk mengisi/mengaitkan ke suatu variabel ke sebuah nilai/objek
#
# | Operator	| Contoh	|
# | --- | --- |
# | Sama dengan `=`	 | `a = 1` |
# | Tambah sama dengan `+=` | 	`a += 2` |
# | Kurang sama dengan `-=`	 | `a -= 2` |
# | Kali sama dengan `*=` | 	`a *= 2` |
# | Bagi sama dengan `/=` | 	`a /= 4` |
# | Sisa bagi sama dengan `%=`	 | `a %= 3` |
# | Pangkat sama dengan `**=` | 	`a **= 3`	 |
# | Pembagian bulat sama dengan `//=` | 	`a //= 3`	 |
#
# Contoh:
# ```python
# tarif_ppn = 0.10
# ```
#
# ## Tip 1: Mendefinisikan 2 variable atau lebih sekaligus
# Kita bisa mengisi dua variable dengan dua nilai sekaligus
#
# Contoh:
# ```python
# a,b,c = 1,2,3
# a = b = c = 4
#
# ```
#
# ## Tip 2: Walrus Operator := (ada di Python 3.8++)
# Operator lain yang bisa digunakan sebagai assignment operator adalah operator walrus. Ini memungkinkan kita untuk menangkap sebuah nilai ke variabel sekaligus mengembalikan nilainya. Walrus menyelesaikan dua tugas sekaligus: menetapkan nilai ke variabel, dan mengembalikan nilai itu
#
# Contoh:
# ```python
#     if jumlah := 10 + 5:
#         print(jumlah)
# ```

# %%
# assign value ke ke variable


# walrus operator

# %% [markdown]
# ## Tipe Data
#
# Berikut adalah tipe data umum yang ada dalam bahasa pemrograman Python :
#
# | Tipe Data     | Contoh                    | Penjelasan                                                                        |
# | ------------- |-------------------------- | --------------------------------------------------------------------------------- |
# | Boolean       |	`True` atau `False`	    | `True` atau salah `False`  |
# | String        |	`"Kemenkeu"`  | karakter/kalimat (diapit tanda `"` atau `'`)|
# | Integer       |	`25` atau `1209`        | bilangan bulat                                                         |
# | Float         |	`3.14` atau `0.99`      | bilangan real                            |
#
# Perintah type() digunakan untuk mengetahui tipe data dari sebuah objek. Contoh: ```type(123)```

# %%
# contoh integer

# contoh string

# contoh boolean

# Periksa tipe data menggunakan type()

# %% [markdown]
# ## Arithmatic Operator
#
# | Operator| 	Contoh	 |
# | --- | --- |
# | Penjumlahan `+`| 	`1 + 3 = 4` |
# | Pengurangan `-`| 	`4 - 1 = 3`	 |
# | Perkalian `*`| 	`2 * 4 = 8`	 |
# | Pembagian `/`| 	`10 / 5 = 2`|
# | Sisa Bagi `%`| 	`11 % 2 = 1`|
# | Pangkat `**`| 	`8 ** 2 = 64`|
# | Pembagian Bulat `//`| 	`10 // 3 = 3` |

# %%
# Penjumlahan (+)

# Pengurangan (-)

# Pembagian (/ atau //)

# Perkalian (*)

# Eksponensial (**)

# Modulo (%)

# %% [markdown]
# ## Logical Operator
#
# Operator perbandingan (comparison operators) digunakan untuk membandingkan suatu nilai
#
# | Operator	| Simbol	|
# | --- | --- |
# | Sama dengan | 	`==`  |
# | Tidak sama dengan |	`!=`  |
# | Tidak sama dengan  |	`<>`  |
# | Lebih besar dari  |	`>`  |
# | Lebih kecil dari |	`<`  |
# | Lebih besar atau sama dengan | `>=` |
# | Lebih kecil atau sama dengan | `<=` |
#
#
# | Operator	| Simbol	|
# | --- | --- |
# | AND | TRUE Jika kedua nilai TRUE |
# | OR  |	TRUE Jika salah satu nilai TRUE  |
# | NOT  | TRUE Jika kedua nilai berbeda |

# %%
# logical operator example

# %% [markdown]
# ## Function
# Fungsi adalah blok kode terorganisir dan dapat digunakan kembali yang digunakan untuk melakukan sebuah tindakan/action.
#
# Mendefinisikan fungsi dengan Python.
#
# - Fungsi blok dimulai dengan  kata kunci **def** diikuti oleh nama fungsi dan tanda kurung (()).
# - Argumen adalah input dari luar fungsi untuk dapat diproses oleh fungsi
# - Return mengembalikan nilai dari proses yang dilakukan
#
# ![image.png](attachment:image.png)

# %%
def nama_fungsi(argumen, argumen):
    # perintah
    return nilai_pengembalian

# %%
def luas_segitiga(alas, tinggi):
    # perintah
    return 
    
def luas_persegi(panjang, lebar = 5):
    # perintah    
    return

# %% [markdown]
# ## Fungsi Lambda
#
# Di Python, kita dapat membuat suatu fungsi sederhana yang mengembalikan nilai, yang pendefinisiannya menggunakan operator lambda.

# %%
# Contoh Lambda Function
fx = lambda x: x**2 + 5*x + 6
fx(4)

# Contoh Lambda Function
luas_segitiga = lambda alas, tinggi: alas * tinggi / 2
luas_segitiga(4, 7)
# Out:
# 14.0

# %% [markdown]
# ## Builtin Functions di Python
#
# Tidak semua fungsi harus anda buat, karena Python sendiri sudah menyediakan berbagai macam fungsi built in.
#
# Contoh:
#
# - ```len()``` untuk mengetahui jumlah karakter pada string, atau jumlah anggota sebuah iterable.
#
# - ```ord()``` yang menghasilkan keluaran berupa nilai int dari sebuah Unicode character.
#
# https://docs.python.org/3/library/functions.html
#
# ### Function/Class Hints
#
# - Shift+Tab
# - ?namafungsi
# - help(fungsi/class))

# %%
# Builtin Functions di Python
ord('🥚') > ord('🐔')


# Function Help and Hint 

# ?ord
# Out:
# True

# %% [markdown]
# ## Data Structure
#
# - List
# - Tuple
# - Dictionary
# - Set

# %% [markdown]
# ### List
#
# List dalam bahasa Python adalah daftar nilai yang dipisahkan koma (item) antara tanda kurung siku. Hal penting tentang daftar adalah item dalam list tidak harus sama jenisnya.
#
# Anggota sebuah list diidentifikasi menggunakan index, index sendiri dimulai dari 0.
#
# Contoh List:
# ```python
# list1 = ['SETJEN', 'DJP', 1993, 2017]
# list2 = [1, 2, 3, 4, 5 ]
# list3 = ["a", "b", "c", "d"]
# ```
#
#
# Terdapat beberapa method yang umum berkaitan dengan list
#
# - ```len(list)```     : Mengetahui panjang list
#
# - ```append(item)```  : Menambahkan sebuah item ke dalam list
#
# - ```extend(list)```  : Mengisi anggota list dengan anggota dari list lain
#
# - ```remove(item)```  : Menghapus sebuah item ke dalam list
#
# - ```count(item)```   : Menghitung keberadaan sebuah item pada sebuah list
#
# - ```index(item)```   : Mengetahui posisi sebuah item pada sebuah list
#
# - ```sort()```  : Mengurutkan item-item dalam list
#
# - ```clear()```   : Mengosongkan nilai list
#
# - ```pop(index)```    : Menghapus anggota list pada posisi tertentu
#
# - ```reverse()``` : Membalikan urutan anggota list

# %% [markdown]
# ## Meengakses anggota List
#
# Untuk mengakses anggota list, gunakan index.
# Contoh:
# ```python
# eselon = ['SETJEN','DJA','DJP','DJBC']
# eselon[0] # 'SETJEN'
# ```
# Menggunakan index negatif berarti mengambil urutan dari belakang
# ```python
# eselon[-1] # 'DJBC'
#
# ```

# %% [markdown]
# ## List Slicing
#
# Slicing adalah mengambil sebagian isi list dengan menggunakan index.
# Ditulis sebagai berikut:
#
# ```python
#     daftar = [1,2,3,4]
#     daftar[start:end:step]
# ```
# Note: end bersifat eksklusif. start,end,step tidak harus didefinisikan
#
# Contoh:
# ```python
#     daftar = [1,2,3,4,5,6,7,8,9]
#     daftar[1:6]
#     daftar[4:]
#     daftar[1:6:2]
#     daftar[-5:-1]
# ```

# %%
# list

# list len, append, remove, count, index

# slicing

# membuat list dari range

# sum, min, max
# Out:
# [1, 2, 3, 5, 6]

# %% [markdown]
# ### Tuple
#
# Adalah kumpulan objek Python seperti list yang tidak dapat diubah nilainya setelah didefinisikan (immutable). Tupel adalah urutan, seperti daftar.
#
#
# ```python
# #Contoh tuple
#
#    kelompok_akun = ('Aset', 'Liabilitias', 'Ekuitas')
#    mutasi_akun = ('Debit','Kredit')
#
# ```

# %%
# tuple

# %% [markdown]
# ### Set
#
# Adalah kumpulan objek Python seperti list yang isinya unik dan berurutan.
#
#
# ```python
#    #Contoh set
#
#    eselon = {"DJA", "DJP", "SETJEN"}
#
# ```
#
# Terdapat beberapa method yang umum berkaitan dengan list
#
# - ```len(set)```     : Mengetahui panjang set
#
# - ```add(item)```  : Menambahkan sebuah item ke dalam set
#
# - ```remove(item)```  : Menghapus sebuah item ke dalam set
#
# - ```count(item)```   : Menghitung keberadaan sebuah item pada sebuah set
#
# - ```index(item)```   : Mengetahui posisi sebuah item pada sebuah set
#
# - ```clear()```   : Mengosongkan nilai set
#
# - ```pop(index)```    : Menghapus anggota set pada posisi tertentu

# %%
# set contoh

# set operation, union intersection
# Out:
# {'DJP'}

# %% [markdown]
# # Dictionary
#
# Adalah kumpulan nilai yang terdiri dari pasangan key dan value.
#
# ```python
#    #Contoh dictionary
#
#    jumlah_pegawai = {
#        'SETJEN' : 2665,
#        'DJP' : 45960,
#        'ITJEN': 715,
#        'DJPK': 547
#    }
# ```
#
# Untuk mengakses nilai dictionary menggunakan somedict[key]
#
# ```python
#    jumlah_pegawai['SETJEN'] # 2655
#
# ```

# %%
# dictionary

# %% [markdown]
# ## Flow Control
#
# - Conditional Statement (If...elif....else...)
# - For Loop
# - While Loop
# - Break Statement
# - Continue Statement
# - Variable Scoping

# %% [markdown]
# ## Conditional Statement (If...elif....else...)
#
# Digunakan untuk mengendalikan kode yang akan dieksekusi dengan memperhatikan pemenuhan terhadap kondisi tertentu.
#
# Syntax:
#
# ```python
#
# if condition1:
#     # baris dieksekusi jika condition1 terpenuhi
# elif condition2:
#     # baris dieksekusi jika condition2 terpenuhi
# else:
#     # baris dieksekusi jika condition1 & condition2 tidak terpenuhi
#
#
# ```
#
# Jika kode kita membutuhkan logika percabangan sederhana, kita bisa menggunakan ternary if. Syntaxnya sebagai berikut:
#
# ```python
#
#    c = a if a < b else b
#
#    a, b = 10, 20
#
#    print("Both a and b are equal" if a == b else "a is not equal to b")
#
# ```

# %%
condition1 = True
condition2 = True

if condition1:
    # baris dieksekusi jika condition1 terpenuhi
    pass
elif condition2:
    # baris dieksekusi jika condition2 terpenuhi
    pass
else:
    # baris dieksekusi jika condition1 & condition2 tidak terpenuhi
    pass
    
# ternary if
a, b = 10, 20
print("Both a and b are equal" if a == b else "a is not equal to b")
# Out:
# a is not equal to b

# %% [markdown]
# ## For Loop
#
# Digunakan untuk mengeksekusi sebuah blok kode secara berulang berdasarkan sebuah iterable
#
# Syntax:
#
# ```python
#
# for i in iterable:
#     # baris dieksekusi pada setiap loop
#
# ```

# %%
# contoh Loop

# %% [markdown]
# ## While Loop
#
# Digunakan untuk mengeksekusi sebuah blok kode secara berulang berdasarkan sebuah kondisi tertentu yang ditetapkan.
#
# ```python
#
# while condition:
#     # baris dieksekusi jika condtion == True
#
# ```

# %%
while condition:
    # baris dieksekusi jika condtion == True

# %% [markdown]
# # Variable Scope
#
# 1. A variable created in the main body of the Python code is a global variable and belongs to the global scope.
#
# ```python
#     x = 300
#     def fungsi():
#       print(x)
#
# ```
#
# 2. A variable created inside a function is available inside that function:
#
# ```python
#    def cek_kelulusan(nilai):
#        lulus = nilai > 50
#        return lulus
#
#    cek_kelulusan()
# ```
#
# 3. The local variable can be accessed from a function within the function:
#
#
# ```python
#    def cek_kelulusan(nilai):
#        nilai = nilai * 100
#        def cek_grade():
#             if nilai > 30:
#                 return True
#             else:
#                 return False
#        return cek_grade()
#
#    cek_kelulusan(2)
# ```
# 4. If you need to create a global variable, but are stuck in the local scope, you can use the global keyword.
#
# ```python
#
# def myfunc():
#   global x
#   x = 300
#
# myfunc()
# print(x)
#
# ```

# %%
# Latihan Scoping
# Out:
# False

# %% [markdown]
# ## Break, Continue dan Pass
#
# - Pass jika dipanggil tidak akan menjalankan apa-apa. Biasanya digunakan jika kita ingin membuat fungsi tapi belum mendefinisikan proses di dalamnya
#
# ```python
# def foo():
#     pass
#
# ```
# - Continue digunakan untuk menghiraukan blok kode setelahnya dan melanjutkan proses iterasi
#
# ```python
# for i in range(1, 10):
#     if i == 5:
#         continue
#     else:
#         print(i)
# ```
# - Break digunakan untuk menghentikan eksekusi kode pada sebuah iterasi
# ```python
# for i in range(1, 10):
#     if i == 5:
#         break
#     else:
#         print(i)
# ```

# %% [markdown]
# ## Libraries
#
#
# Contoh:
# - pandas
# - math
# - statistics
# - matplotlib
# - scikit
# - nltk
# - keras
#
# ## Cara Install Library
# Untuk menginstall pustaka / library pihak ketiga kita bisa menggunakan perintah:
# 1. ```pip install nama_library``` atau
# 2. ```pip i nama_library```
#
# ## Cara Menggunakan Library
# Untuk menggunakan sebuah library kita perlu melakukan import
#
# Contoh:
# ```python
# import math
#
# math.pi
# ```
#
# Kita bisa menggunakan aliasing untuk library yang kita import
#
# ```python
# import numpy as np
# np.sqrt(9)
# ```
#
# Kita bise melakukan import beberapa bagian saja pada library
#
# ```python
# from fibo import fib, fib2
# fib(500)
# ```

# %%
# Cara Import Library
# Out:
# 3.0
