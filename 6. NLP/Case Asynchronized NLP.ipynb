# %% [markdown]
# # Natural Language Processing
# ## study case: film opinion text processing
#
# oleh:
# <br> Ade Satya Wahana
# <br> I Gede Yudi Paramartha

# %%
#import libraries yang diperlukan
import pandas as pd
import re

# list tanda baca 
from string import punctuation

# stemmer bahasa indonesia
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# stopwords bahasa indonesia
from nltk.corpus import stopwords
stop = list(stopwords.words('indonesian'))


pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# C:\Users\ade.satya\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %% [markdown]
# ### LOAD DATASET

# %%
dataset = pd.read_csv('dataset_tweet_sentiment_opini_film.csv')
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id          200 non-null    int64
#  1   Sentiment   200 non-null    object
#  2   Text Tweet  200 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.8+ KB

# %%
dataset.head(5)
# Out:
#    Id Sentiment  \
# 0  1   negative
# 1  2   negative
# 2  3   negative
# 3  4   negative
# 4  5   negative
#
#                                                                                                       Text Tweet
# 0  Jelek filmnya... apalagi si ernest gak mutu bgt actingnya... film sampah
# 1  Film king Arthur ini film paling jelek dari seluruh cerita King Arthur
# 2  @beexkuanlin Sepanjang film gwa berkata kasar terus pada bapaknya
# 3  Ane ga suka fast and furious..menurutku kok jelek ya tu film
# 4  @baekhyun36 kan gua ga tau film nya, lu bilang perang perangan/? Perang"an disebut ama rp yaoi jadi ambigu :v

# %% [markdown]
# ### Text Normalization
# #### Lowercasing

# %%
# isikan stepnya disini, gunakan kolom Text Tweet dan simpan di kolom baru Text Lower

# %%
dataset.head(5)
# Out:
#    Id Sentiment  \
# 0  1   negative
# 1  2   negative
# 2  3   negative
# 3  4   negative
# 4  5   negative
#
#                                                                                                       Text Tweet  \
# 0  Jelek filmnya... apalagi si ernest gak mutu bgt actingnya... film sampah
# 1  Film king Arthur ini film paling jelek dari seluruh cerita King Arthur
# 2  @beexkuanlin Sepanjang film gwa berkata kasar terus pada bapaknya
# 3  Ane ga suka fast and furious..menurutku kok jelek ya tu film
# 4  @baekhyun36 kan gua ga tau film nya, lu bilang perang perangan/? Perang"an disebut ama rp yaoi jadi ambigu :v
#
#                                                                                                       Text Lower
# 0  jelek filmnya... apalagi si ernest gak mutu bgt actingnya... film sampah
# 1  film king arthur ini film paling jelek dari seluruh cerita king arthur
# 2  @beexkuanlin sepanjang film gwa berkata kasar terus pada bapaknya
# 3  ane ga suka fast and furious..menurutku kok jelek ya tu film
# 4  @baekhyun36 kan gua ga tau film nya, lu bilang perang perangan/? perang"an disebut ama rp yaoi jadi ambigu :v

# %% [markdown]
# ### Text Cleansing
# #### handle tweet unique parts

# %%
#menghilangkan/menyatukan http atau https menjadi satu tokens (URL)
#pengerjaan masih di kolom yang sama (Tweet Clean)

dataset['Tweet Clean'] = dataset['Tweet Clean'].replace(to_replace=r'(http|https)\S+', value='URL', regex=True)

# %%
# menghilangkan/menyatukan # menjadi satu tokens (HASHTAG)
#baik untuk #dengan kata atau #dengan angka

# %%
# menghilangkan/menyatukan @ menjadi satu tokens (TAGGING)
# baik untuk @dengan kata atau @dengan angka
# pengerjaan masih di kolom yang sama (Tweet Clean)

# %%
dataset['Tweet Clean'] = dataset['Tweet Clean'].str.strip()
dataset.head()
# Out:
#    Id Sentiment  \
# 0  1   negative
# 1  2   negative
# 2  3   negative
# 3  4   negative
# 4  5   negative
#
#                                                                                                       Text Tweet  \
# 0  Jelek filmnya... apalagi si ernest gak mutu bgt actingnya... film sampah
# 1  Film king Arthur ini film paling jelek dari seluruh cerita King Arthur
# 2  @beexkuanlin Sepanjang film gwa berkata kasar terus pada bapaknya
# 3  Ane ga suka fast and furious..menurutku kok jelek ya tu film
# 4  @baekhyun36 kan gua ga tau film nya, lu bilang perang perangan/? Perang"an disebut ama rp yaoi jadi ambigu :v
#
#                                                                                                       Text Lower  \
# 0  jelek filmnya... apalagi si ernest gak mutu bgt actingnya... film sampah
# 1  film king arthur ini film paling jelek dari seluruh cerita king arthur
# 2  @beexkuanlin sepanjang film gwa berkata kasar terus pada bapaknya
# 3  ane ga suka fast and furious..menurutku kok jelek ya tu film
# 4  @baekhyun36 kan gua ga tau film nya, lu bilang perang perangan/? perang"an disebut ama rp yaoi jadi ambigu :v
#
#                                                                                                  Tweet Clean
# 0  jelek filmnya... apalagi si ernest gak mutu bgt actingnya... film sampah
# 1  film king arthur ini film paling jelek dari seluruh cerita king arthur
# 2  TAGGING sepanjang film gwa berkata kasar terus pada bapaknya
# 3  ane ga suka fast and furious..menurutku kok jelek ya tu film
# 4  TAGGING kan gua ga tau film nya, lu bilang perang perangan/? perang"an disebut ama rp yaoi jadi ambigu :v

# %% [markdown]
# #### Apakah sebaiknya unique parts tersebut dihapus atau dikumpulkan menjadi satu token? Mengapa?

# %% [markdown]
# Jawab disini:

# %% [markdown]
# #### Remove Number

# %%
# menghapus angka pada tweet (menjadi empty space ''), gunakan kolom Tweet Clean dan simpan di kolom yang sama
# gunakan regex \d untuk mencari angka

# %%
dataset['Tweet Clean'] = dataset['Tweet Clean'].str.strip()
dataset.tail()
# Out:
#       Id Sentiment  \
# 195  196  positive
# 196  197  positive
# 197  198  positive
# 198  199  positive
# 199  200  positive
#
#                                                                                                                                        Text Tweet  \
# 195  Fargo juga adaptasi dari film yang cukup berhasil. Season 1-nya the best! https://t.co/tkEEK3Evs9
# 196  637.000 waw ini sangat keren flm horor dng jumlah penonton segini dlm waktu 4 hari @prillybie @danurmovie
# 197  @filmziarah film yang tenang dan menghanyutkan. Salut dengan Mbah Ponco yg bisa membawakan karakter Mbah Sri dengan sangat baik. #FilmZiarah
# 198  Film yg amat menarik. Kisah cinta & kesetiaan yg disajikan secara tidak biasa. Bikin kgn nenek. Recomended movie @filmziarah #meiberziarah
# 199  Nntn @filmziarah , film bagus, ada kali 5 menit penonton gak beranjak tetep ngliatin layar pdhl film dah selesai, msh spicles sm endingnya
#
#                                                                                                                                        Text Lower  \
# 195  fargo juga adaptasi dari film yang cukup berhasil. season 1-nya the best! https://t.co/tkeek3evs9
# 196  637.000 waw ini sangat keren flm horor dng jumlah penonton segini dlm waktu 4 hari @prillybie @danurmovie
# 197  @filmziarah film yang tenang dan menghanyutkan. salut dengan mbah ponco yg bisa membawakan karakter mbah sri dengan sangat baik. #filmziarah
# 198  film yg amat menarik. kisah cinta & kesetiaan yg disajikan secara tidak biasa. bikin kgn nenek. recomended movie @filmziarah #meiberziarah
# 199  nntn @filmziarah , film bagus, ada kali 5 menit penonton gak beranjak tetep ngliatin layar pdhl film dah selesai, msh spicles sm endingnya
#
#                                                                                                                                Tweet Clean
# 195  fargo juga adaptasi dari film yang cukup berhasil. season -nya the best! URL
# 196  . waw ini sangat keren flm horor dng jumlah penonton segini dlm waktu  hari TAGGING TAGGING
# 197  TAGGING film yang tenang dan menghanyutkan. salut dengan mbah ponco yg bisa membawakan karakter mbah sri dengan sangat baik. HASHTAG
# 198  film yg amat menarik. kisah cinta & kesetiaan yg disajikan secara tidak biasa. bikin kgn nenek. recomended movie TAGGING HASHTAG
# 199  nntn TAGGING , film bagus, ada kali  menit penonton gak beranjak tetep ngliatin layar pdhl film dah selesai, msh spicles sm endingnya

# %% [markdown]
# #### Remove Punctuation

# %%
#count punctuation before implementation
dataset['Tweet Clean'].map(lambda v: any(char in v for char in punctuation)).sum()
# Out:
# 175

# %%
#remove_puctuations functions
def remove_punctuations(text):
    # tuliskan algoritma remove punctuationnya
    

# apply fungsinya pada kolom tweet clean dan simpan pada kolom baru Punct Removed
dataset['Punct Removed'] = dataset['Tweet Clean'].apply(remove_punctuations)

# %%
dataset['Punct Removed'] = dataset['Punct Removed'].str.strip()
# cek count lagi
print('sisa punct:',dataset['Punct Removed'].map(lambda v: any(char in v for char in punctuation)).sum())

dataset.head()
# Out:
# sisa punct: 0
#    Id Sentiment  \
# 0  1   negative
# 1  2   negative
# 2  3   negative
# 3  4   negative
# 4  5   negative
#
#                                                                                                       Text Tweet  \
# 0  Jelek filmnya... apalagi si ernest gak mutu bgt actingnya... film sampah
# 1  Film king Arthur ini film paling jelek dari seluruh cerita King Arthur
# 2  @beexkuanlin Sepanjang film gwa berkata kasar terus pada bapaknya
# 3  Ane ga suka fast and furious..menurutku kok jelek ya tu film
# 4  @baekhyun36 kan gua ga tau film nya, lu bilang perang perangan/? Perang"an disebut ama rp yaoi jadi ambigu :v
#
#                                                                                                       Text Lower  \
# 0  jelek filmnya... apalagi si ernest gak mutu bgt actingnya... film sampah
# 1  film king arthur ini film paling jelek dari seluruh cerita king arthur
# 2  @beexkuanlin sepanjang film gwa berkata kasar terus pada bapaknya
# 3  ane ga suka fast and furious..menurutku kok jelek ya tu film
# 4  @baekhyun36 kan gua ga tau film nya, lu bilang perang perangan/? perang"an disebut ama rp yaoi jadi ambigu :v
#
#                                                                                                  Tweet Clean  \
# 0  jelek filmnya... apalagi si ernest gak mutu bgt actingnya... film sampah
# 1  film king arthur ini film paling jelek dari seluruh cerita king arthur
# 2  TAGGING sepanjang film gwa berkata kasar terus pada bapaknya
# 3  ane ga suka fast and furious..menurutku kok jelek ya tu film
# 4  TAGGING kan gua ga tau film nya, lu bilang perang perangan/? perang"an disebut ama rp yaoi jadi ambigu :v
#
#                                                                                           Punct Removed
# 0  jelek filmnya apalagi si ernest gak mutu bgt actingnya film sampah
# 1  film king arthur ini film paling jelek dari seluruh cerita king arthur
# 2  TAGGING sepanjang film gwa berkata kasar terus pada bapaknya
# 3  ane ga suka fast and furiousmenurutku kok jelek ya tu film
# 4  TAGGING kan gua ga tau film nya lu bilang perang perangan perangan disebut ama rp yaoi jadi ambigu v

# %% [markdown]
# ##### Apa semua tanda baca tidak memiliki relevansi dalam mendeteksi sentiment? mengapa?

# %% [markdown]
# jawab disini:

# %% [markdown]
# #### Remove Slang Words

# %%
# load file slang word 
normalized_slang = pd.read_excel('Slang_word.xlsx')
normalized_slang.head()
# Out:
#   Tidak_baku    Baku
# 0  ane        saya
# 1  tu         itu
# 2  gua        saya
# 3  lu         kamu
# 4  dgn        dengan

# %%
def remove_slang(text):
    # tuliskan algoritma untuk mereplace kata tidak baku menjadi kata baku
    

# apply fungsinya pada kolom Punct Removed dan simpan pada kolom baru Slang Removed
dataset['Slang Removed'] = dataset['Punct Removed'].apply(remove_slang)

# %%
dataset['Slang Removed'] = dataset['Slang Removed'].str.strip()
dataset.head()
# Out:
#    Id Sentiment  \
# 0  1   negative
# 1  2   negative
# 2  3   negative
# 3  4   negative
# 4  5   negative
#
#                                                                                                       Text Tweet  \
# 0  Jelek filmnya... apalagi si ernest gak mutu bgt actingnya... film sampah
# 1  Film king Arthur ini film paling jelek dari seluruh cerita King Arthur
# 2  @beexkuanlin Sepanjang film gwa berkata kasar terus pada bapaknya
# 3  Ane ga suka fast and furious..menurutku kok jelek ya tu film
# 4  @baekhyun36 kan gua ga tau film nya, lu bilang perang perangan/? Perang"an disebut ama rp yaoi jadi ambigu :v
#
#                                                                                                       Text Lower  \
# 0  jelek filmnya... apalagi si ernest gak mutu bgt actingnya... film sampah
# 1  film king arthur ini film paling jelek dari seluruh cerita king arthur
# 2  @beexkuanlin sepanjang film gwa berkata kasar terus pada bapaknya
# 3  ane ga suka fast and furious..menurutku kok jelek ya tu film
# 4  @baekhyun36 kan gua ga tau film nya, lu bilang perang perangan/? perang"an disebut ama rp yaoi jadi ambigu :v
#
#                                                                                                  Tweet Clean  \
# 0  jelek filmnya... apalagi si ernest gak mutu bgt actingnya... film sampah
# 1  film king arthur ini film paling jelek dari seluruh cerita king arthur
# 2  TAGGING sepanjang film gwa berkata kasar terus pada bapaknya
# 3  ane ga suka fast and furious..menurutku kok jelek ya tu film
# 4  TAGGING kan gua ga tau film nya, lu bilang perang perangan/? perang"an disebut ama rp yaoi jadi ambigu :v
#
#                                                                                           Punct Removed  \
# 0  jelek filmnya apalagi si ernest gak mutu bgt actingnya film sampah
# 1  film king arthur ini film paling jelek dari seluruh cerita king arthur
# 2  TAGGING sepanjang film gwa berkata kasar terus pada bapaknya
# 3  ane ga suka fast and furiousmenurutku kok jelek ya tu film
# 4  TAGGING kan gua ga tau film nya lu bilang perang perangan perangan disebut ama rp yaoi jadi ambigu v
#
#                                                                                                  Slang Removed
# 0  jelek filmnya apalagi si ernest gak mutu sangat actingnya film sampah
# 1  film king arthur ini film paling jelek dari seluruh cerita king arthur
# 2  TAGGING sepanjang film saya berkata kasar terus pada bapaknya
# 3  saya tidak suka fast and furiousmenurutku kok jelek ya itu film
# 4  TAGGING kan saya tidak tahu film nya kamu bilang perang perangan perangan disebut ama rp yaoi jadi ambigu v

# %% [markdown]
# #### Remove Stopwords

# %%
# keluarkan kata tidak dalam list stopwords

print(len(stop))
stop.remove('tidak')
print(len(stop))
# Out:
# 758
# 757

# %%
def remove_stopword(text):
# tulis di sini codenya, 
    

# apply pada kolom Slang Removed dan simpan di kolom baru Stopwords Removed
dataset['Stopwords Removed'] = dataset['Slang Removed'].apply(remove_stopword)

# %%
dataset['Stopwords Removed'] = dataset['Stopwords Removed'].str.strip()
dataset.head()
# Out:
#    Id Sentiment  \
# 0  1   negative
# 1  2   negative
# 2  3   negative
# 3  4   negative
# 4  5   negative
#
#                                                                                                       Text Tweet  \
# 0  Jelek filmnya... apalagi si ernest gak mutu bgt actingnya... film sampah
# 1  Film king Arthur ini film paling jelek dari seluruh cerita King Arthur
# 2  @beexkuanlin Sepanjang film gwa berkata kasar terus pada bapaknya
# 3  Ane ga suka fast and furious..menurutku kok jelek ya tu film
# 4  @baekhyun36 kan gua ga tau film nya, lu bilang perang perangan/? Perang"an disebut ama rp yaoi jadi ambigu :v
#
#                                                                                                       Text Lower  \
# 0  jelek filmnya... apalagi si ernest gak mutu bgt actingnya... film sampah
# 1  film king arthur ini film paling jelek dari seluruh cerita king arthur
# 2  @beexkuanlin sepanjang film gwa berkata kasar terus pada bapaknya
# 3  ane ga suka fast and furious..menurutku kok jelek ya tu film
# 4  @baekhyun36 kan gua ga tau film nya, lu bilang perang perangan/? perang"an disebut ama rp yaoi jadi ambigu :v
#
#                                                                                                  Tweet Clean  \
# 0  jelek filmnya... apalagi si ernest gak mutu bgt actingnya... film sampah
# 1  film king arthur ini film paling jelek dari seluruh cerita king arthur
# 2  TAGGING sepanjang film gwa berkata kasar terus pada bapaknya
# 3  ane ga suka fast and furious..menurutku kok jelek ya tu film
# 4  TAGGING kan gua ga tau film nya, lu bilang perang perangan/? perang"an disebut ama rp yaoi jadi ambigu :v
#
#                                                                                           Punct Removed  \
# 0  jelek filmnya apalagi si ernest gak mutu bgt actingnya film sampah
# 1  film king arthur ini film paling jelek dari seluruh cerita king arthur
# 2  TAGGING sepanjang film gwa berkata kasar terus pada bapaknya
# 3  ane ga suka fast and furiousmenurutku kok jelek ya tu film
# 4  TAGGING kan gua ga tau film nya lu bilang perang perangan perangan disebut ama rp yaoi jadi ambigu v
#
#                                                                                                  Slang Removed  \
# 0  jelek filmnya apalagi si ernest gak mutu sangat actingnya film sampah
# 1  film king arthur ini film paling jelek dari seluruh cerita king arthur
# 2  TAGGING sepanjang film saya berkata kasar terus pada bapaknya
# 3  saya tidak suka fast and furiousmenurutku kok jelek ya itu film
# 4  TAGGING kan saya tidak tahu film nya kamu bilang perang perangan perangan disebut ama rp yaoi jadi ambigu v
#
#                                                              Stopwords Removed
# 0  jelek filmnya si ernest gak mutu actingnya film sampah
# 1  film king arthur film jelek cerita king arthur
# 2  TAGGING film kasar bapaknya
# 3  tidak suka fast and furiousmenurutku jelek ya film
# 4  TAGGING tidak film nya bilang perang perangan perangan ama rp yaoi ambigu v

# %% [markdown]
# #### Mengapa step remove stopword dilakukan setelah step mengubah slang words?

# %% [markdown]
# Jawab di sini:

# %% [markdown]
# #### Mengapa kata 'tidak' dikeluarkan dari list stopwords yang akan dibersihkan?

# %% [markdown]
# Jawab disini:

# %% [markdown]
# #### Stemming (pengembalian kata ke kata dasar)

# %%
# load stemmer dari package sastrawi yang telah di import 
stemmer = StemmerFactory().create_stemmer()

# %%
def stem_sentences(sentence):
#tulis step-step pengaplikasian stemmer di atas
    

# apply fungsi diatas pada kolom Stopwords Removed dan simpan pada kolom baru Stem tweet
dataset['Stem tweet'] = dataset['Stopwords Removed'].apply(stem_sentences)

# %%
dataset['Stem tweet'] = dataset['Stem tweet'].str.strip()
dataset.tail()
# Out:
#       Id Sentiment  \
# 195  196  positive
# 196  197  positive
# 197  198  positive
# 198  199  positive
# 199  200  positive
#
#                                                                                                                                        Text Tweet  \
# 195  Fargo juga adaptasi dari film yang cukup berhasil. Season 1-nya the best! https://t.co/tkEEK3Evs9
# 196  637.000 waw ini sangat keren flm horor dng jumlah penonton segini dlm waktu 4 hari @prillybie @danurmovie
# 197  @filmziarah film yang tenang dan menghanyutkan. Salut dengan Mbah Ponco yg bisa membawakan karakter Mbah Sri dengan sangat baik. #FilmZiarah
# 198  Film yg amat menarik. Kisah cinta & kesetiaan yg disajikan secara tidak biasa. Bikin kgn nenek. Recomended movie @filmziarah #meiberziarah
# 199  Nntn @filmziarah , film bagus, ada kali 5 menit penonton gak beranjak tetep ngliatin layar pdhl film dah selesai, msh spicles sm endingnya
#
#                                                                                                                                        Text Lower  \
# 195  fargo juga adaptasi dari film yang cukup berhasil. season 1-nya the best! https://t.co/tkeek3evs9
# 196  637.000 waw ini sangat keren flm horor dng jumlah penonton segini dlm waktu 4 hari @prillybie @danurmovie
# 197  @filmziarah film yang tenang dan menghanyutkan. salut dengan mbah ponco yg bisa membawakan karakter mbah sri dengan sangat baik. #filmziarah
# 198  film yg amat menarik. kisah cinta & kesetiaan yg disajikan secara tidak biasa. bikin kgn nenek. recomended movie @filmziarah #meiberziarah
# 199  nntn @filmziarah , film bagus, ada kali 5 menit penonton gak beranjak tetep ngliatin layar pdhl film dah selesai, msh spicles sm endingnya
#
#                                                                                                                                Tweet Clean  \
# 195  fargo juga adaptasi dari film yang cukup berhasil. season -nya the best! URL
# 196  . waw ini sangat keren flm horor dng jumlah penonton segini dlm waktu  hari TAGGING TAGGING
# 197  TAGGING film yang tenang dan menghanyutkan. salut dengan mbah ponco yg bisa membawakan karakter mbah sri dengan sangat baik. HASHTAG
# 198  film yg amat menarik. kisah cinta & kesetiaan yg disajikan secara tidak biasa. bikin kgn nenek. recomended movie TAGGING HASHTAG
# 199  nntn TAGGING , film bagus, ada kali  menit penonton gak beranjak tetep ngliatin layar pdhl film dah selesai, msh spicles sm endingnya
#
#                                                                                                                           Punct Removed  \
# 195  fargo juga adaptasi dari film yang cukup berhasil season nya the best URL
# 196  waw ini sangat keren flm horor dng jumlah penonton segini dlm waktu  hari TAGGING TAGGING
# 197  TAGGING film yang tenang dan menghanyutkan salut dengan mbah ponco yg bisa membawakan karakter mbah sri dengan sangat baik HASHTAG
# 198  film yg amat menarik kisah cinta  kesetiaan yg disajikan secara tidak biasa bikin kgn nenek recomended movie TAGGING HASHTAG
# 199  nntn TAGGING  film bagus ada kali  menit penonton gak beranjak tetep ngliatin layar pdhl film dah selesai msh spicles sm endingnya
#
#                                                                                                                                 Slang Removed  \
# 195  fargo juga adaptasi dari film yang cukup berhasil season nya the best URL
# 196  waw ini sangat keren flm horor dng jumlah penonton segini dlm waktu  hari TAGGING TAGGING
# 197  TAGGING film yang tenang dan menghanyutkan salut dengan mbah ponco yang bisa membawakan karakter mbah sri dengan sangat baik HASHTAG
# 198  film yang amat menarik kisah cinta  kesetiaan yang disajikan secara tidak biasa bikin kgn nenek recomended movie TAGGING HASHTAG
# 199  nntn TAGGING  film bagus ada kali  menit penonton gak beranjak tetep lihat layar padahal film dah selesai masih spicles dengan endingnya
#
#                                                                                                  Stopwords Removed  \
# 195  fargo adaptasi film berhasil season nya the best URL
# 196  waw keren flm horor dng penonton segini dlm TAGGING TAGGING
# 197  TAGGING film tenang menghanyutkan salut mbah ponco membawakan karakter mbah sri HASHTAG
# 198  film menarik kisah cinta kesetiaan disajikan tidak bikin kgn nenek recomended movie TAGGING HASHTAG
# 199  nntn TAGGING film bagus kali menit penonton gak beranjak tetep lihat layar film dah selesai spicles endingnya
#
#                                                                                                    Stem tweet
# 195  fargo adaptasi film hasil season nya the best url
# 196  waw keren flm horor dng tonton gin dlm tagging tagging
# 197  tagging film tenang hanyut salut mbah ponco bawa karakter mbah sri hashtag
# 198  film tarik kisah cinta setia saji tidak bikin kgn nenek recomended movie tagging hashtag
# 199  nntn tagging film bagus kali menit tonton gak anjak tetep lihat layar film dah selesai spicles endingnya

# %% [markdown]
# #### Remove short words (less than 3 characters)

# %%
def remove_short(text):
    # tulis step untuk meremove kata-kata yang singkat 1-2 character
    
# gunakan kolom Stem tweet dan simpan pada kolom baru Short-Tokens
dataset['Short-Tokens'] = dataset['Stem tweet'].apply(remove_short)

# %%
dataset['Short-Tokens'] = dataset['Short-Tokens'].str.strip()
dataset.head()
# Out:
#    Id Sentiment  \
# 0  1   negative
# 1  2   negative
# 2  3   negative
# 3  4   negative
# 4  5   negative
#
#                                                                                                       Text Tweet  \
# 0  Jelek filmnya... apalagi si ernest gak mutu bgt actingnya... film sampah
# 1  Film king Arthur ini film paling jelek dari seluruh cerita King Arthur
# 2  @beexkuanlin Sepanjang film gwa berkata kasar terus pada bapaknya
# 3  Ane ga suka fast and furious..menurutku kok jelek ya tu film
# 4  @baekhyun36 kan gua ga tau film nya, lu bilang perang perangan/? Perang"an disebut ama rp yaoi jadi ambigu :v
#
#                                                                                                       Text Lower  \
# 0  jelek filmnya... apalagi si ernest gak mutu bgt actingnya... film sampah
# 1  film king arthur ini film paling jelek dari seluruh cerita king arthur
# 2  @beexkuanlin sepanjang film gwa berkata kasar terus pada bapaknya
# 3  ane ga suka fast and furious..menurutku kok jelek ya tu film
# 4  @baekhyun36 kan gua ga tau film nya, lu bilang perang perangan/? perang"an disebut ama rp yaoi jadi ambigu :v
#
#                                                                                                  Tweet Clean  \
# 0  jelek filmnya... apalagi si ernest gak mutu bgt actingnya... film sampah
# 1  film king arthur ini film paling jelek dari seluruh cerita king arthur
# 2  TAGGING sepanjang film gwa berkata kasar terus pada bapaknya
# 3  ane ga suka fast and furious..menurutku kok jelek ya tu film
# 4  TAGGING kan gua ga tau film nya, lu bilang perang perangan/? perang"an disebut ama rp yaoi jadi ambigu :v
#
#                                                                                           Punct Removed  \
# 0  jelek filmnya apalagi si ernest gak mutu bgt actingnya film sampah
# 1  film king arthur ini film paling jelek dari seluruh cerita king arthur
# 2  TAGGING sepanjang film gwa berkata kasar terus pada bapaknya
# 3  ane ga suka fast and furiousmenurutku kok jelek ya tu film
# 4  TAGGING kan gua ga tau film nya lu bilang perang perangan perangan disebut ama rp yaoi jadi ambigu v
#
#                                                                                                  Slang Removed  \
# 0  jelek filmnya apalagi si ernest gak mutu sangat actingnya film sampah
# 1  film king arthur ini film paling jelek dari seluruh cerita king arthur
# 2  TAGGING sepanjang film saya berkata kasar terus pada bapaknya
# 3  saya tidak suka fast and furiousmenurutku kok jelek ya itu film
# 4  TAGGING kan saya tidak tahu film nya kamu bilang perang perangan perangan disebut ama rp yaoi jadi ambigu v
#
#                                                              Stopwords Removed  \
# 0  jelek filmnya si ernest gak mutu actingnya film sampah
# 1  film king arthur film jelek cerita king arthur
# 2  TAGGING film kasar bapaknya
# 3  tidak suka fast and furiousmenurutku jelek ya film
# 4  TAGGING tidak film nya bilang perang perangan perangan ama rp yaoi ambigu v
#
#                                                                 Stem tweet  \
# 0  jelek film si ernest gak mutu actingnya film sampah
# 1  film king arthur film jelek cerita king arthur
# 2  tagging film kasar bapak
# 3  tidak suka fast and furiousmenurutku jelek ya film
# 4  tagging tidak film nya bilang perang perang perang ama rp yaoi ambigu v
#
#                                                          Short-Tokens
# 0  jelek film ernest gak mutu actingnya film sampah
# 1  film king arthur film jelek cerita king arthur
# 2  tagging film kasar bapak
# 3  tidak suka fast and furiousmenurutku jelek film
# 4  tagging tidak film nya bilang perang perang perang ama yaoi ambigu

# %% [markdown]
# #### Mengapa kata pendek harus dihapus?

# %%
Jawab di sini:
